# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
test = pd.read_csv("/content/drive/MyDrive/4laptops.csv")
test
# Out:
#     Manufacturer       Model_Name   Category  Screen_size_inches  \
# 0          Apple      MacBook Pro  Ultrabook                13.3
# 1          Apple      Macbook Air  Ultrabook                13.3
# 2             HP           250 G6   Notebook                15.6
# 3          Apple      MacBook Pro  Ultrabook                15.4
# 4          Apple      MacBook Pro  Ultrabook                13.3
# ..           ...              ...        ...                 ...
# 972         Dell     Alienware 17     Gaming                17.3
# 973      Toshiba  Tecra A40-C-1DF   Notebook                14.0
# 974         Asus        Rog Strix     Gaming                17.3
# 975           HP      Probook 450   Notebook                15.6
# 976       Lenovo    ThinkPad T460   Notebook                14.0
#
#                                  Screen                          CPU   RAM  \
# 0    IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz   8GB
# ...

# %%
test["Weight_kg"].mean()
# Out:
# 2.0391279426816786

# %%
test["Weight_kg"].median()
# Out:
# 2.02

# %%
test["Weight_kg"].mode()
# Out:
# 0    2.2
# Name: Weight_kg, dtype: float64

# %%
test["Screen_size_inches"].median()
# Out:
# 15.6

# %%
test["Screen_size_inches"].mode()
# Out:
# 0    15.6
# Name: Screen_size_inches, dtype: float64

# %%
test["Price"].mean()
# Out:
# 10018994.56028659

# %%
test["Price"].median()
# Out:
# 8527428.0

# %%
test["Category"].value_counts()
# Out:
# Notebook              549
# Ultrabook             152
# Gaming                150
# 2 in 1 Convertible     85
# Workstation            24
# Netbook                17
# Name: Category, dtype: int64

# %%
test["Category"].mode()
# Out:
# 0    Notebook
# Name: Category, dtype: object

# %%
test = pd.read_csv("/content/drive/MyDrive/5ds_salaries.csv")
test
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
test["work_year"].mode()
# Out:
# 0    2023
# Name: work_year, dtype: int64

# %%
test["salary"].mean()
# Out:
# 190695.57177097205

# %%
test["salary"].mode()
# Out:
# 0    100000
# Name: salary, dtype: int64

# %%
test["salary_in_usd"].mean()
# Out:
# 137570.38988015978

# %%
test["employee_residence"].mode()
# Out:
# 0    US
# Name: employee_residence, dtype: object

# %%
test["remote_ratio"].median()
# Out:
# 0.0

# %%
test = pd.read_csv("/content/drive/MyDrive/7games.csv")
test
# Out:
#       Unnamed: 0                                    Title Release_Date  \
# 0              0                               Elden Ring    25-Feb-22
# 1              1                                    Hades    10-Dec-19
# 2              2  The Legend of Zelda: Breath of the Wild     3-Mar-17
# 3              3                                Undertale    15-Sep-15
# 4              4                          Hollow 000night    24-Feb-17
# ...          ...                                      ...          ...
# 1507        1507           Bac000 to the Future: The Game    22-Dec-10
# 1508        1508                        Team Sonic Racing    21-May-19
# 1509        1509                           Dragon's Dogma    22-May-12
# 1510        1510                          Baldur's Gate 3     6-Oct-20
# 1511        1511                 The LEGO Movie Videogame     4-Feb-14
#
#                                                    Team  Rating  Times_Listed  \
# ...

# %%
test["Rating"].mean()
# Out:
# 3.7193462308205465

# %%
test["Times_Listed"].median()
# Out:
# 551.0

# %%
test["Number_of_Reviews"].mean()
# Out:
# 4352.79298941799

# %%
test["Plays"].mean()
# Out:
# 30211.3167989418

# %%
test["Playing"].mean()
# Out:
# 1035.2367724867725

# %%
test["Genres"].mode()
# Out:
# 0    ['Adventure', 'RPG']
# Name: Genres, dtype: object
